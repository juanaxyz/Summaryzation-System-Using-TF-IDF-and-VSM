# %% [markdown]
# # Prerequisites

# %%
# %pip install -r requirements.txt

# %% [markdown]
# # Load file artikel

# %%
from pathlib import Path
import pandas as pd

article_path = Path("article.md")
article = article_path.read_text(encoding="utf-8")

print(f"Loaded: {article_path} ({len(article)} karakter)")
print(article)  # preview

# %% [markdown]
# # Proses

# %% [markdown]
# ## Pecah menjadi beberapa paragraph

# %%
from preprocess import splitDocument, splitParagraph, preprocess

# ambil query dari heading pertama markdown
first_nonempty_line = next((line.strip() for line in article.splitlines() if line.strip()), "")
# print(f"First non-empty line: {first_nonempty_line}")
query = first_nonempty_line.lstrip("#").strip()
print(f"Query: {query}")
query_tokens = preprocess(query)

paragraph = splitParagraph(article)
print(f"Split into {len(paragraph)} paragraphs")

# %% [markdown]
# ## Proses setiap Paragraph

# %%
from information_retrieval import tfCounter


print(f"Query Tokens: {query_tokens}\n")
for k, v in paragraph.items():
    print(f"Paragraph {k}: {v[:20]}...\n")  # preview
    docs = splitDocument(v)
    
    tf = tfCounter(query_tokens[0], docs[0])
    print(tf)
    # for i,doc in enumerate(docs):
    #     # df_tf = pd.DataFrame(
    #     #     [tfCounter([t], [doc]) for t in query_tokens],
    #     #     index=query_tokens
    #     # )
    #     # print(df_tf)
    #     clean_doc = preprocess(doc)
    #     print(f"Document-{i+1}: {clean_doc}\n")
        
    
        # print(f"Kalimat: {s}")
        # print(f"Preprocessed: {preprocess(s)}")
        # print("===============================")
